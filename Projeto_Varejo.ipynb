# %% [markdown]
# <a href="https://colab.research.google.com/github/siqdaniel/Case_RH/blob/main/Projeto_Varejo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('Verificar link')
# Out:
# Verificar link
